# %% [markdown]
# <h2 style="color: orangered; background-color: bisque;"> <b> Project:2 </b> EDA</h2>

# %% [markdown]
# > <h3>Import Required Libraries</h3>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, Markdown

# %% [markdown]
# > <h3>Load Dataset</h3>

# %%
data=pd.read_csv("clean_data.csv")

# %% [markdown]
# > <h3>Dataset View</h3>

# %%
data.shape
# Out:
# (1200, 14)

# %%
data.head()
# Out:
#      OrderID        Date CustomerID  Product  Quantity  UnitPrice  \
# 0  ORD200000  2023-01-04     C72649  Monitor         5     570.62
# 1  ORD200001  2024-08-23     C75739    Phone         2     151.35
# 2  ORD200002  2024-02-27     C81728   Tablet         5     550.68
# 3  ORD200003  2023-10-15     C33540    Chair         1     273.19
# 4  ORD200004  2025-05-08     C81840  Printer         4     626.01
#
#   ShippingAddress PaymentMethod OrderStatus TrackingNumber  ItemsInCart  \
# 0     928 Main St    Debit Card     Shipped    TRK37947903            7
# 1     823 Main St        Online     Shipped    TRK91186779            3
# 2     512 Main St   Credit Card   Cancelled    TRK42903982            8
# 3     275 Main St    Debit Card    Returned    TRK62788070            5
# 4     668 Main St        Online   Delivered    TRK29241424            8
#
#   CouponCode ReferralSource  TotalPrice
# 0     SAVE10      Instagram     2853.10
# 1     SAVE10       Referral      302.70
# ...

# %%
data.tail()
# Out:
#         OrderID        Date CustomerID  Product  Quantity  UnitPrice  \
# 1195  ORD201195  2024-06-20     C21126     Desk         1     107.04
# 1196  ORD201196  2024-03-04     C20095  Monitor         2     662.53
# 1197  ORD201197  2023-07-13     C79674   Tablet         2     436.84
# 1198  ORD201198  2024-08-22     C64753    Chair         4     262.52
# 1199  ORD201199  2023-06-11     C57502   Tablet         4     560.58
#
#      ShippingAddress PaymentMethod OrderStatus TrackingNumber  ItemsInCart  \
# 1195     392 Main St   Credit Card   Cancelled    TRK38009181            6
# 1196     778 Main St        Online   Cancelled    TRK69207593            5
# 1197     275 Main St        Online   Delivered    TRK88039356            2
# 1198     509 Main St    Debit Card   Cancelled    TRK71683331            4
# 1199     201 Main St     Gift Card    Returned    TRK51116746            6
#
#      CouponCode ReferralSource  TotalPrice
# 1195   FREESHIP         Google      107.04
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OrderID          1200 non-null   object
#  1   Date             1200 non-null   object
#  2   CustomerID       1200 non-null   object
#  3   Product          1200 non-null   object
#  4   Quantity         1200 non-null   int64
#  5   UnitPrice        1200 non-null   float64
#  6   ShippingAddress  1200 non-null   object
#  7   PaymentMethod    1200 non-null   object
#  8   OrderStatus      1200 non-null   object
#  9   TrackingNumber   1200 non-null   object
#  10  ItemsInCart      1200 non-null   int64
#  11  CouponCode       891 non-null    object
#  12  ReferralSource   1200 non-null   object
#  13  TotalPrice       1200 non-null   float64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 131.4+ KB

# %%
data.sample(10)
# Out:
#         OrderID        Date CustomerID  Product  Quantity  UnitPrice  \
# 96    ORD200096  2024-06-01     C93007    Phone         2     232.83
# 1017  ORD201017  2024-08-25     C51694    Chair         2     680.85
# 696   ORD200696  2023-07-02     C22429    Chair         4     151.20
# 871   ORD200871  2024-05-16     C93768   Tablet         3     324.30
# 684   ORD200684  2024-09-22     C96583  Printer         4      34.84
# 357   ORD200357  2023-07-08     C74982   Laptop         5     408.56
# 838   ORD200838  2024-04-11     C57798     Desk         4     577.08
# 146   ORD200146  2025-04-30     C84645   Tablet         2     411.49
# 53    ORD200053  2024-05-18     C67551    Phone         4     488.78
# 235   ORD200235  2023-02-20     C32854     Desk         1      65.45
#
#      ShippingAddress PaymentMethod OrderStatus TrackingNumber  ItemsInCart  \
# 96       103 Main St     Gift Card   Delivered    TRK85696091            7
# ...

# %% [markdown]
# > <h3>Check for Duplicate Rows</h3>

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# > <h3>Check for Missing Values</h3>

# %%
missing_value=data.isnull().sum().sum()
# Out:
# <h2 style="color: red;"> Missing Values Found</h2>
# OrderID              0
# Date                 0
# CustomerID           0
# Product              0
# Quantity             0
# UnitPrice            0
# ShippingAddress      0
# PaymentMethod        0
# OrderStatus          0
# TrackingNumber       0
# ItemsInCart          0
# CouponCode         309
# ReferralSource       0
# TotalPrice           0
# dtype: int64

# %%
print("--- Numerical Summary ---")
display(data[['Quantity', 'UnitPrice', 'TotalPrice', 'ItemsInCart']].describe())
# Out:
# --- Numerical Summary ---
#           Quantity    UnitPrice   TotalPrice  ItemsInCart
# count  1200.000000  1200.000000  1200.000000  1200.000000
# mean      2.945833   356.412750  1053.968300     5.485000
# std       1.407557   197.177146   819.856558     2.281983
# min       1.000000    11.390000    11.390000     1.000000
# 25%       2.000000   186.062500   410.520000     4.000000
# 50%       3.000000   364.210000   823.615000     5.000000
# 75%       4.000000   521.570000  1578.475000     7.000000
# max       5.000000   699.930000  3456.400000    10.000000

# %%
print("\n--- Top Products Sold ---")
display(data['Product'].value_counts())
# Out:
# --- Top Products Sold ---
# Product
# Printer    181
# Tablet     179
# Chair      178
# Laptop     173
# Desk       170
# Monitor    163
# Phone      156
# Name: count, dtype: int64

# %%
print("\n--- Preferred Payment Methods ---")
display(data['PaymentMethod'].value_counts(normalize=True) * 100)
# Out:
# --- Preferred Payment Methods ---
# PaymentMethod
# Online         21.500000
# Cash           20.500000
# Credit Card    19.500000
# Debit Card     19.333333
# Gift Card      19.166667
# Name: proportion, dtype: float64

# %%
correlation_matrix = data[numerical_cols].corr()
sns.heatmap(correlation_matrix,
             annot=True,
             cmap='coolwarm', 
             fmt=".2f")

plt.title('Correlation Matrix')
plt.show()

# %%
sns.boxplot(x=data['TotalPrice'], color='orangered')
plt.title('Outlier in Total Order Price')
plt.xlabel('Total Price')
plt.show()

# Calculate IQR to identify exact outlier thresholds
Q1 = data['TotalPrice'].quantile(0.25)
Q3 = data['TotalPrice'].quantile(0.75)
IQR = Q3 - Q1
upper_bound = Q3 + (1.5 * IQR)

outliers = data[data['TotalPrice'] > upper_bound]
print(f"Number of outlier orders (> ${upper_bound:.2f}): {len(outliers)}")
# Out:
# Number of outlier orders (> $3330.41): 8

# %%
outliers = data[data['TotalPrice'] > upper_bound]
normal_data = data[data['TotalPrice'] <= upper_bound]

plt.scatter(
    normal_data.index, 
    normal_data['TotalPrice'], 
    color='steelblue', 
    alpha=0.5, 
    s=25, 
    label='Normal Orders'
)

plt.scatter(
    outliers.index, 
    outliers['TotalPrice'], 
    color='red', 
    marker='x', 
    s=70, 
    linewidths=2, 
    label=f'Outliers (> ${upper_bound:.2f})'
)

plt.axhline(
    y=upper_bound, 
    color='orangered', 
    linestyle='--', 
    linewidth=1.5, 
    label=f'IQR Threshold Boundary (${upper_bound:.2f})'
)

# 5. Polish the aesthetics
plt.title('Identified Outliers', fontsize=14, fontweight='bold', pad=15)
plt.xlabel('Order Sequence', fontsize=11)
plt.ylabel('Total Transaction Value ($)', fontsize=11)
plt.grid(True, linestyle=':', alpha=0.6)
plt.legend(loc='upper right', frameon=True, shadow=True)

# Render
plt.tight_layout()
plt.show()

# %%
# Aggregate sales by Month-Year to see macroeconomic trends
data["Date"] = pd.to_datetime(data["Date"], errors="coerce")
data["YearMonth"] = data["Date"].dt.to_period("M")
monthly_sales =data.groupby('YearMonth')['TotalPrice'].sum().reset_index()
monthly_sales['YearMonth'] = monthly_sales['YearMonth'].astype(str)

plt.figure(figsize=(14, 5))
sns.lineplot(data=monthly_sales, x='YearMonth', y='TotalPrice', marker='o', color='purple')
plt.xticks(rotation=45)
plt.title('Revenue Trend Analysis (2023 - 2025)',fontsize=20)
plt.ylabel('Total Sales Revenue ($)')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
# --- 1. Calculate Revenue Drivers ---
product_sales = data.groupby('Product')['TotalPrice'].sum()
top_product = product_sales.idxmax()
top_product_rev = product_sales.max()
bottom_product = product_sales.idxmin()
bottom_product_rev = product_sales.min()

# --- 2. Calculate Customer Behavior (Mean vs Median) ---
mean_val = data['TotalPrice'].mean()
median_val = data['TotalPrice'].median()

# Determine skewness / outlier direction
if mean_val > median_val:
    skew_explanation = "high-value outliers (large individual purchases) are pulling the average upward"
else:
    skew_explanation = "low-value bulk orders are pulling the average downward"

# --- 3. Identify Trend Performance ---
# Convert date to Year-Month period for grouping
data['YearMonth'] = pd.to_datetime(data['Date']).dt.to_period('M')
monthly_sales = data.groupby('YearMonth')['TotalPrice'].sum()
peak_month = monthly_sales.idxmax()
peak_month_val = monthly_sales.max()

# Format the peak month (e.g., "January 2024")
peak_month_str = peak_month.to_timestamp().strftime('%B %Y')

# --- 4. Operational Risk Metrics ---
status_counts = data['OrderStatus'].value_counts()
returned_count = status_counts.get('Returned', 0)
cancelled_count = status_counts.get('Cancelled', 0)
total_orders = len(data)
risk_percentage = ((returned_count + cancelled_count) / total_orders) * 100

# Find high-risk referral channels for returns/cancellations
risk_orders = data[data['OrderStatus'].isin(['Returned', 'Cancelled'])]
referral_risk = risk_orders['ReferralSource'].value_counts(normalize=True) * 100
top_risk_source = referral_risk.idxmax() if not referral_risk.empty else "Unknown"
top_risk_pct = referral_risk.max() if not referral_risk.empty else 0

# --- 5. Generate Completed Markdown ---
completed_summary = f"""
## 📊 Executive Summary & Key Observations
Based on the descriptive analysis of the {total_orders:,} orders in this dataset:

* **Revenue Drivers:** **{top_product}** represents the highest volume of sales (generating ${top_product_rev:,.2f}), whereas **{bottom_product}** is lagging behind (generating ${bottom_product_rev:,.2f}).
* **Customer Behavior:** The average transaction value (Mean) is **${mean_val:.2f}**, but the Median is **${median_val:.2f}**, indicating that **{skew_explanation}**.
* **Trend Performance:** Revenue experienced a significant growth trend peaking in **{peak_month_str}** (reaching ${peak_month_val:,.2f} in monthly sales), likely driven by high transaction counts and the utilization of the `SAVE10` or `FREESHIP` coupon codes. 
* **Operational Risk:** We noticed that **{risk_percentage:.1f}%** of total orders ({returned_count} returned, {cancelled_count} cancelled) did not result in a successful completion. Our referral source analysis indicates that traffic coming from **{top_risk_source}** represents the highest share of these lost conversions (**{top_risk_pct:.1f}%** of all cancelled/returned orders), which warrants immediate operational review.
"""

display(Markdown(completed_summary))
# Out:
# ## 📊 Executive Summary & Key Observations
# Based on the descriptive analysis of the 1,200 orders in this dataset:
#
# * **Revenue Drivers:** **Chair** represents the highest volume of sales (generating $195,620.11), whereas **Phone** is lagging behind (generating $151,722.39).
# * **Customer Behavior:** The average transaction value (Mean) is **$1053.97**, but the Median is **$823.62**, indicating that **high-value outliers (large individual purchases) are pulling the average upward**.
# * **Trend Performance:** Revenue experienced a significant growth trend peaking in **June 2024** (reaching $68,068.54 in monthly sales), likely driven by high transaction counts and the utilization of the `SAVE10` or `FREESHIP` coupon codes.
# ...
